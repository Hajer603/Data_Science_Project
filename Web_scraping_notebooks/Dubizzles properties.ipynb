# %% [markdown]
# # **Dubizzle scrapping**

# %%
# Used to send HTTP requests to fetch web pages from the internet (HTML content)
import requests
#Parses HTML or XML documents so you can extract and navigate page content easily
from bs4 import BeautifulSoup
#Powerful tool for storing, processing, and exporting data in tabular form (e.g., CSV or Excel)
import pandas as pd
#Supports regular expressions for pattern matching inside strings (e.g., extracting numbers, units)
import re  
#Provides sleep functionality to pause the script (helps avoid getting blocked during scraping)
import time 
# Built-in module to handle JSON data: reading from APIs or saving data to .json files
import json

# %%
base_url = 'https://www.dubizzle.com.om'
cadr_url = f"{base_url}/en/properties/properties-for-sale/"
current_link = base_url

# %%
r = requests.get(base_url) # will send a req for get and will save the res into a variable called 'r'
print(r)
# Out:
# <Response [200]>

# %%
print(f'Without BeautifulSoup: {r.content}') # This will print unreadable data and we cant deal with it.
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
# Here the power of BeautifulSoup comes to convert the 'r.content'to readable data.
soup = BeautifulSoup(r.content, 'html') # here what happend is we called a function 'BeautifulSoup' to parse the unreadable 'r.content' to the readable and specify what we want to parse in our setuation is html
print(soup)
# Now we can identify the element what we want to fetch by their classes, id's, elements
# Out:
# <!DOCTYPE html>
# <html dir="rtl" itemscope="" itemtype="http://schema.org/WebPage" lang="ar"><head><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1.0, user-scalable=0" name="viewport"/><link href="https://ll8iz711cs-dsn.algolia.net" rel="dns-prefetch"/><link href="https://www.googletagmanager.com" rel="dns-prefetch"/><link href="https://www.google-analytics.com" rel="dns-prefetch"/><link href="https://images.bayut.com" rel="dns-prefetch"/><link href="/assets/apple-touch-icon.318a683f5e331c46c23eb3742a9f3d49.png" rel="apple-touch-icon" sizes="180x180"/><link href="/assets/favicon-16x16.771c69f9ab365d2b39ca63a11a5edc57.png" rel="icon" sizes="16x16" type="image/png"/><link href="/assets/favicon-32x32.db52812416fd3c125e3502aabf54bacf.png" rel="icon" sizes="32x32" type="image/png"/><link crossorigin="use-credentials" href="/assets/413f1a7b03c790e9715b21d365d5283a.json" rel="manifest"/><link color="#28b16d" href="/assets/safari-pinned-tab.4f01bd49d15cf8e03fa01e92f1c03adb.svg" rel="mask-icon"/><meta content="#e00000" name="theme-color"/><title>دوبيزل (أوليكس) - بيع وشراء مجانًا في أي مكان في عُمان على موقع دوبيزل (أوليكس) للإعلانات المبوبة</title><meta content="تصفح أكثر من 1000 إعلان على دوبيزل (أوليكس) في عُمان. تصفح إعلانات السيارات والأثاث والإلكترونيات والوظائف والخدمات. قم ببيع وشراء أي شيء اليوم!" name="description"/><link href="https://www.dubizzle.com.om/" rel="canonical"/><meta content="ar" http-equiv="Content-Language"/><meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/><meta content="on" http-equiv="cleartype"/><meta content="True" name="HandheldFriendly"/><meta content="320" name="MobileOptimized"/><link href="https://www.dubizzle.com.om/" hreflang="ar" rel="alternate"/><link href="https://www.dubizzle.com.om/en/" hreflang="en" rel="alternate"/><script type="application/ld+json">{"@context":"https://schema.org","@type":"WebSite","name":"OLX Oman","alternateName":"OLX Oman","url":"https://www.dubizzle.com.om/"}</script><script type="application/ld+json">{"@context":"https://schema.org","@type":"Organization","name":"دوبيزل عُمان (أوليكس)","url":"https://www.dubizzle.com.om/","image":{"@type":"ImageObject","url":"/assets/logo_noinline.7406374f4f87797b5bdd806a6b03cbd3.svg"},"logo":{"@type":"ImageObject","url":"/assets/logo_noinline.7406374f4f87797b5bdd806a6b03cbd3.svg"}}</script><script>window['dataLayer'] = window['dataLayer'] || [];window['dataLayer'].push({"experiments":{},"device_type":"d","app_agent_version":"1.0","app_agent":"web","app_environment":"production","language":"ar","lang":"ar","area_unit":"Sq. M.","currency_unit":"OMR","layout_preference":"list","url":"https:\u002F\u002Fwww.dubizzle.com.om\u002F","query_params":"?","route":{"routeName":"home","routeParams":{},"url":"\u002F","originalURL":"\u002F","referrer":null,"originalReferrer":null,"landingURL":"\u002F"},"referrer":null,"website_referrer":null,"starting_page_url":"https:\u002F\u002Fwww.dubizzle.com.om\u002F","anonymous_session_id":"160caba2-761c-4cc9-be2c-7fb5873d4d17","user_profile":{"userStatus":"Anonymous"},"website_platform":"strat","thumb_uid":"-1","loc_id":"0-1","loc_name":"Oman","loc_breadcrumb":";0-1;","website_section":"main_site","is_agent":"no","page_type":"home","page_number":1,"fresh_recommendations":["130333529","130397716","130065084","130419921","120297495","130451150","130470054","130168723","130447947","129933150","129402876","129996156","130080860","130427265","120504498","129702027","130447058","130427257","130433983","130477880","130456455","129702039","129694835","129693363","130474377","130467016","128923361","128892354","130441568","130488445","130329620","130419431"],"popular_categories":["1453","84","81","1721","729","1455","40"]});</script><script id="runtimeSettings">window.CONFIG={runtime: Object.assign({"CANONICAL_DOMAIN":"www.dubizzle.com.om","CANONICAL_DOMAIN_EXCEPTION":[""],"COOKIE_DOMAIN":null,"DISABLE_EXPERIMENTS":false,"EXPERIMENTS_OVERRIDE_VARIANT":null,"EXPERIMENTS":null,"MOENGAGE_DATA_CENTER":" ...
#                         window['dataLayer'] = window['dataLayer'] || [];
#                         window['dataLayer'].push({
#                             'gtm.start': new Date().getTime(),
#                             event: 'gtm.js',
#                         });
#                     </script></head><body><noscript><iframe class="_00fc8592" src="https://www.googletagmanager.com/ns.html?id=GTM-KJMKX43"></iframe></noscript><div class="_31a7ce0c f55e23e5" id="body-wrapper"><div class="_948d9e0a _95d4067f _1e086faf _4122130d"><header class="_364b6f18"><div class="b8e180fa"><div class="b6da2e8f"><a class="_7a00c34b" href="/"><svg alt="Logo" class="ade3c907" fill="none" viewbox="0 0 65 36"><path d="M24.86 33.1l.1-.94c.25 0 .45 0 .6-.04a.65.65 0 0 0 .38-.26c.1-.15.2-.37.29-.67.1-.3.2-.73.32-1.27l.85.24a62.15 62.15 0 0 0-.2.94 2.6 2.6 0 0 0-.05.46c0 .2.07.34.21.44.15.1.4.16.78.16.23 0 .42-.02.56-.06a.59.59 0 0 0 .35-.27c.1-.14.18-.37.26-.7.08-.31.16-.74.24-1.29l.86.16-.08.5-.1.6a4.1 4.1 0 0 0-.02.46c0 .1.02.2.06.3.06.1.15.17.3.22.15.05.37.08.67.08.22 0 .4-.03.56-.08a.6.6 0 0 0 .38-.3c.1-.14.13-.34.13-.6 0-.28-.07-.64-.2-1.07a16.5 16.5 0 0 0-.44-1.3l.91-.34a10.82 10.82 0 0 1 .5 1.74c.06.33.1.6.1.83 0 .35-.05.66-.14.92a1.7 1.7 0 0 1-1 1.06 2.5 2.5 0 0 1-.82.1c-.35 0-.64-.03-.87-.1-.22-.1-.4-.22-.52-.4a1.5 1.5 0 0 1-.24-.65h.39c-.14.33-.3.57-.45.74a1.2 1.2 0 0 1-.6.34c-.23.05-.54.08-.92.08-.15 0-.35-.03-.6-.1a1.1 1.1 0 0 1-.53-.34 1.37 1.37 0 0 1-.28-.8l.34-.07c-.13.38-.3.67-.48.86-.18.18-.4.3-.65.36a4 4 0 0 1-.91.1z" fill="#212223"></path><path d="M25.04 33.1c-.6 0-1.07-.08-1.4-.21a1.18 1.18 0 0 1-.65-.64 3.17 3.17 0 0 1-.24-1.1l-.23-6.2h.93l.1 2.91.13 2.92c0 .37.05.66.1.86.05.2.19.33.37.4.2.08.52.12.95.12.16 0 .28.05.34.14.08.08.12.18.12.3s-.06.24-.16.34c-.1.1-.24.15-.4.15zm-6.15 0l.1-.94c.34 0 .63-.02.85-.07a.74.74 0 0 0 .48-.27c.1-.14.15-.35.15-.63 0-.2-.02-.4-.1-.67a17.1 17.1 0 0 0-.55-1.71l.93-.34a10.82 10.82 0 0 1 .5 1.74 3.18 3.18 0 0 1 0 1.6 1.8 1.8 0 0 1-.3.63c-.13.16-.3.3-.5.4-.2.1-.42.17-.69.22a5.4 5.4 0 0 1-.9.07zm1.2 2.09a.56.56 0 0 1-.4-.17.56.56 0 0 1 .4-.95.5.5 0 0 1 .4.17c.1.1.16.24.16.4a.5.5 0 0 1-.17.38.5.5 0 0 1-.38.17z" fill="#212223"></path><path d="M13.46 33.1l.1-.94h.59a15.03 15.03 0 0 0 1.17-.1 2.75 2.75 0 0 0 1.21-.42c.23-.14.4-.3.54-.5.15-.2.22-.42.22-.68 0-.17-.04-.35-.13-.53a1.4 1.4 0 0 0-.34-.48.72.72 0 0 0-.5-.19.83.83 0 0 0-.5.18 1.4 1.4 0 0 0-.5 1.07c0 .24.05.46.17.65a2 2 0 0 0 .46.5c.18.13.36.24.55.32l-1.08.32a2.74 2.74 0 0 1-.86-1 2.18 2.18 0 0 1 1.05-2.79 1.74 1.74 0 0 1 1.72.13c.28.2.5.46.65.78.16.3.24.63.24.97a2.1 2.1 0 0 1-.68 1.58c-.2.2-.45.38-.73.52a4.68 4.68 0 0 1-2.06.54 9.54 9.54 0 0 1-1.29.06zm5.6 0a10.68 10.68 0 0 1-2.3-.27 5.66 5.66 0 0 1-.9-.27l.78-.57a23.37 23.37 0 0 0 2.54.13c.16 0 .27.05.34.14.08.08.1.18.1.3s-.04.24-.14.34a.6.6 0 0 1-.41.15zm-2-5.93a.58.58 0 0 1-.42-.16.56.56 0 0 1-.16-.4.56.56 0 0 1 .57-.57.5.5 0 0 1 .4.17.54.54 0 0 1 0 .8c-.1.1-.25.16-.4.16zm-1.56 0a.58.58 0 0 1-.4-.16.56.56 0 0 1-.17-.4.56.56 0 0 1 .57-.57.5.5 0 0 1 .38.17.54.54 0 0 1 0 .8c-.1.1-.23.16-.38.16z" fill="#212223"></path><path d="M13.64 33.1c-.6 0-1.07-.08-1.4-.21a1.18 1.18 0 0 1-.65-.64 3.17 3.17 0 0 1-.2-1.1l-.23-6.2h.93l.23 5.83c0 .37.05.66.1.86.06.2.19.33.38.4.2.08.53.12.96.12.15 0 .27.05.34.14.07.08.1.18.1.3s-.04.24-.15.34c-.1.1-.24.15-.4.15zm-3.22-11v-.63l2.54-.75v.65l-2.54.73zm0 1.2v-.64l2.54-.75v.64l-2.54.74z" fill="#212223"></path><path clip-rule="evenodd" d="M48.4 33.8h-2.42V23.55h2.42V33.8zm-3.29-5.1a4.21 4.21 0 1 1-8.43 0 4.21 4.21 0 0 1 8.43 0zm-2.94 0a1.27 1.27 0 1 0-2.55 0 1.27 1.27 0 0 0 2.55 0zm12.38-2.57h-1.61l-.95.95-.94-.95h-1.61v1.64l.93.93-.93.93v1.62h1.63l.93-.93.92.93h1.64v-1.62l-.94-.93.94-.93v-1.64z" fill="#212223" fill-rule="evenodd"></path><g clip-path="url(#a)" clip-rule="evenodd" fill-rule="evenodd"><path d="M42.8 12.24c-.33.25-.54.6-.9 1.06a54.45 54.45 0 0 0-2.36 3.3c-.4.6-.78 1.13-1.1 1.75h4.45v1.78h-6.9v-1.35c.33-.48.58-1 .94-1.57l1.12-1.7a66.38 66.38 0 0 1 2.15-3.02h-3.98v-1.8h6.58v1.54zm8.13 0a40.84 40.84 0 0 0-1.97 2.59c-.4.56-.8 1.16-1.21 1.76-.4.61-.77 1.14-1.1 1.76h4.38v1.78h-6.78v-1.35c.31-.48.55-1 .9-1.57a92.92 92.92 0 0 1 2.26-3.35l1-1.37h-3.95v-1.8h6.47v1.54zm3.87-5.92h-.03c-.34 0-1.82.26-2.16.6v13.2h2.18V6.32zm7.53 8.16c0 ...
#
#
#
# window.webpackBundles = {"browser.css":{"publicPath":"\u002Fassets\u002Fmain.desktop.1851a6ed02824863.rtl.css","contents":null},"browser.js":{"publicPath":"\u002Fassets\u002Fmain.desktop.3a97e2ea484eda40.js","contents":null}};
# window.webpackBundles["browser.css"].contents = document.getElementById("browserStyles").textContent.toString();window.webpackBundles["preloadedStyles"] = Array.from(document.querySelectorAll("[data-preload-type=style]")).map(function (el) {  return {    publicPath: el.dataset.href,    contents: el.innerHTML  };});window.webpackBundles["preloadedScripts"] = Array.from(document.querySelectorAll("[data-preload-type=script]")).map(function (el) {  return {    publicPath: el.attributes.href.value,    contents: null  };});</script><script defer="" src="/assets/locale/ar/main.messages.9841a9d3d1e77ee4150635ad5226423d7b282dbc.js"></script><script defer="" src="/assets/main.desktop.3a97e2ea484eda40.js"></script></body></html>

# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd

# Dictionary to hold scraped data
dubizzle_data = {
    'property_name': [],
    'sale_price': [],
    'prop_location': [],
    'prop_area': [],
    'prop_bathrooms': [],
    'number_of_rooms': []
}

# Safely extract text from an element
def extract_text(element, default="not mentioned"):
    return element.get_text(strip=True) if element else default

# Extract relevant data from each property card
def extract_card_data(card):
    title = extract_text(card.find('h2', class_='_562a2db2'))
    price = extract_text(card.find('span', class_='ddc1b288'), "price not mentioned")
    location = extract_text(card.find('span', class_='f7d5e47e'), "no location mentioned")

    def extract_feature(label):
        section = card.find('span', attrs={'aria-label': label})
        value = section.find('span', class_='_3e1113f0') if section else None
        return extract_text(value)

    return {
        'title': title,
        'price': price,
        'location': location,
        'area': extract_feature("Area"),
        'baths': extract_feature("Bathrooms"),
        'rooms': extract_feature("Beds")  # Changed 'beds' to 'rooms'
    }

# Scrape one page and collect data
def scrape_page(session, url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0 Safari/537.36'
    }
    res = session.get(url, headers=headers)
    soup = BeautifulSoup(res.content, 'html.parser')
    listings = soup.find_all('li', attrs={'aria-label': 'Listing'})
    print(f"Found {len(listings)} listings on {url}")

    for card in listings:
        data = extract_card_data(card)
        dubizzle_data['property_name'].append(data.get('title', 'not mentioned'))
        dubizzle_data['sale_price'].append(data.get('price', 'not mentioned'))
        dubizzle_data['prop_location'].append(data.get('location', 'not mentioned'))
        dubizzle_data['prop_area'].append(data.get('area', 'not mentioned'))
        dubizzle_data['prop_bathrooms'].append(data.get('baths', 'not mentioned'))
        dubizzle_data['number_of_rooms'].append(data.get('rooms', 'not mentioned'))

# Main loop to scrape all pages
with requests.Session() as session:
    base_url = "https://www.dubizzle.com.om/en/properties/properties-for-sale/"
    for page_num in range(1, 105):  # Adjust page range as needed
        if page_num == 1:
            url = base_url
        else:
            url = f"{base_url}?page={page_num}"
        print(f"Scraping page {page_num}: {url}")
        scrape_page(session, url)
        time.sleep(15)  # polite delay to avoid blocking

print("Sale property scraping complete!")

# Export to CSV
df = pd.DataFrame(dubizzle_data)
df.to_csv("dubizzle_oman_sale_properties.csv", index=False, encoding='utf-8-sig')
print("Data saved to 'dubizzle_oman_sale_properties.csv'")
# Out:
# Scraping page 1: https://www.dubizzle.com.om/en/properties/properties-for-sale/
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/
# Scraping page 2: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=2
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=2
# Scraping page 3: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=3
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=3
# Scraping page 4: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=4
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=4
# Scraping page 5: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=5
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=5
# Scraping page 6: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=6
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=6
# Scraping page 7: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=7
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=7
# Scraping page 8: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=8
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=8
# Scraping page 9: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=9
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=9
# Scraping page 10: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=10
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=10
# Scraping page 11: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=11
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=11
# Scraping page 12: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=12
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=12
# Scraping page 13: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=13
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=13
# Scraping page 14: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=14
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=14
# Scraping page 15: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=15
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=15
# Scraping page 16: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=16
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=16
# Scraping page 17: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=17
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=17
# Scraping page 18: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=18
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=18
# Scraping page 19: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=19
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=19
# Scraping page 20: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=20
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=20
# Scraping page 21: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=21
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=21
# Scraping page 22: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=22
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=22
# Scraping page 23: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=23
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=23
# Scraping page 24: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=24
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=24
# Scraping page 25: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=25
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=25
# Scraping page 26: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=26
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=26
# Scraping page 27: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=27
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=27
# Scraping page 28: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=28
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=28
# Scraping page 29: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=29
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=29
# Scraping page 30: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=30
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=30
# Scraping page 31: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=31
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=31
# Scraping page 32: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=32
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=32
# Scraping page 33: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=33
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=33
# Scraping page 34: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=34
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=34
# Scraping page 35: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=35
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=35
# Scraping page 36: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=36
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=36
# Scraping page 37: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=37
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=37
# Scraping page 38: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=38
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=38
# Scraping page 39: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=39
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=39
# Scraping page 40: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=40
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=40
# Scraping page 41: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=41
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=41
# Scraping page 42: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=42
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=42
# Scraping page 43: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=43
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=43
# Scraping page 44: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=44
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=44
# Scraping page 45: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=45
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=45
# Scraping page 46: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=46
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=46
# Scraping page 47: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=47
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=47
# Scraping page 48: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=48
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=48
# Scraping page 49: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=49
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=49
# Scraping page 50: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=50
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=50
# Scraping page 51: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=51
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=51
# Scraping page 52: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=52
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=52
# Scraping page 53: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=53
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=53
# Scraping page 54: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=54
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=54
# Scraping page 55: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=55
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=55
# Scraping page 56: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=56
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=56
# Scraping page 57: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=57
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=57
# Scraping page 58: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=58
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=58
# Scraping page 59: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=59
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=59
# Scraping page 60: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=60
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=60
# Scraping page 61: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=61
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=61
# Scraping page 62: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=62
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=62
# Scraping page 63: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=63
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=63
# Scraping page 64: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=64
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=64
# Scraping page 65: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=65
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=65
# Scraping page 66: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=66
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=66
# Scraping page 67: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=67
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=67
# Scraping page 68: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=68
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=68
# Scraping page 69: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=69
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=69
# Scraping page 70: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=70
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=70
# Scraping page 71: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=71
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=71
# Scraping page 72: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=72
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=72
# Scraping page 73: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=73
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=73
# Scraping page 74: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=74
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=74
# Scraping page 75: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=75
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=75
# Scraping page 76: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=76
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=76
# Scraping page 77: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=77
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=77
# Scraping page 78: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=78
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=78
# Scraping page 79: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=79
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=79
# Scraping page 80: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=80
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=80
# Scraping page 81: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=81
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=81
# Scraping page 82: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=82
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=82
# Scraping page 83: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=83
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=83
# Scraping page 84: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=84
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=84
# Scraping page 85: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=85
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=85
# Scraping page 86: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=86
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=86
# Scraping page 87: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=87
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=87
# Scraping page 88: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=88
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=88
# Scraping page 89: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=89
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=89
# Scraping page 90: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=90
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=90
# Scraping page 91: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=91
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=91
# Scraping page 92: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=92
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=92
# Scraping page 93: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=93
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=93
# Scraping page 94: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=94
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=94
# Scraping page 95: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=95
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=95
# Scraping page 96: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=96
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=96
# Scraping page 97: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=97
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=97
# Scraping page 98: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=98
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=98
# Scraping page 99: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=99
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=99
# Scraping page 100: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=100
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=100
# Scraping page 101: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=101
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=101
# Scraping page 102: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=102
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=102
# Scraping page 103: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=103
# Found 45 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=103
# Scraping page 104: https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=104
# Found 26 listings on https://www.dubizzle.com.om/en/properties/properties-for-sale/?page=104
# Sale property scraping complete!
# Data saved to 'dubizzle_oman_sale_properties.csv'

# %%
df
# Out:
#                                           property_name   sale_price  \
# 0     Furnished 3-Bedroom Lakefront Villa for Sale i...  OMR 249,000
# 1     Luxury Apartment|Mouj Muscat |Freehold Ownersh...  OMR 125,000
# 2        5 BR Spacious Villa in Azaiba Nearby Amenities  OMR 197,000
# 3     Two Bedroom Seaview Apartment at Mandarin Orie...  OMR 405,000
# 4                    Villa for Sale (Garden) - Sea View  OMR 517,000
# ...                                                 ...          ...
# 4656            شقة مفروشة مميزة للبيع في الخوض السابعة   OMR 38,900
# 4657                                أرض الطيب موقع جميل    OMR 2,200
# 4658  all types of interlock avaialble watsapp me 95...    OMR 2,000
# 4659  فرصة ذهبية بمخطط الوطن المقابل للمعبيلة 8 بكاف...   OMR 31,000
# 4660  ارض سكنيه للبيع ولايه بركاء\n\n*مربع الهرم الم...   OMR 16,500
#
#                    prop_location prop_area prop_bathrooms number_of_rooms
# 0               Salalah, Dhofar•   573 SQM              3               3
# 1     The Wave (Almouj), Muscat•   110 SQM              2               1
# 2                Azaiba, Muscat•   600 SQM              4               5
# 3                 Qurum, Muscat•   131 SQM              3               2
# 4                  Yiti, Muscat•   506 SQM              6               4
# ...                          ...       ...            ...             ...
# 4656           Al Khoud, Muscat•    76 SQM              2               2
# 4657          Ibri, Al Dhahirah•   600 SQM  not mentioned   not mentioned
# 4658          Al Rusayl, Muscat•    10 SQM  not mentioned   not mentioned
# 4659          Barka, Al Batinah•   600 SQM  not mentioned   not mentioned
# 4660          Barka, Al Batinah•   600 SQM  not mentioned   not mentioned
#
# [4661 rows x 6 columns]
